# %%
import matplotlib
import matplotlib.pyplot as plt
import torch
# %matplotlib inline
import tqdm
import numpy as np
from JulienNet import JulienNet

import torchvision
import random

# %%
dropout = False

# %%
from JulienNet import SetGenerator
CIFAR_10_Generator = SetGenerator(100,100)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
plt.imshow(CIFAR_10_Generator.show_random())

# %%
from JulienNet import JNetTrainer
Trainer = JNetTrainer(CIFAR_10_Generator,200,dropout,'JNet_No_dropout.pth')
# Trainer.train()
Trainer.load('Jnet.pth')
# Out:
# cuda:0

# %%
fig,ax=plt.subplots(1,2)
ax[0].plot(Trainer.train_loss_list,color='k')
ax[0].plot(Trainer.val_loss_list,color='g')

ax[0].set(title="Loss",xlabel="n_epochs",ylabel="loss")


ax[1].plot(Trainer.train_accuracy_list,color='b')
ax[1].plot(Trainer.val_accuracy_list,color='r')
ax[1].set(title="Loss",xlabel="n_epochs",ylabel="accuracy")
plt.show()

# %%
# np.save('training models/Nodropout/training_accuracy',Trainer.train_accuracy_list)
# np.save('training models/Nodropout/val_accuracy',Trainer.val_accuracy_list)
# np.save('training models/Nodropout/training_loss',Trainer.train_loss_list)
# np.save('training models/Nodropout/val_loss',Trainer.val_loss_list)

# %%
net = JulienNet(True)
net.load_state_dict(torch.load('Jnet.pth'))

net = Trainer.net


no_of_layers=0
conv_layers=[]
 
model_children=list(net.children())
 
for child in model_children:
  if type(child)==torch.nn.Conv2d:
    no_of_layers+=1
    conv_layers.append(child)
  elif type(child)==torch.nn.Sequential:
    for layer in child.children():
      if type(layer)==torch.nn.Conv2d:
        no_of_layers+=1
        conv_layers.append(layer)
print(no_of_layers)

img = Trainer.SetGenerator.training_set[random.randint(9,len(Trainer.SetGenerator.training_set))][0]

plt.imshow(Trainer.SetGenerator.imshow(torchvision.utils.make_grid(img)))

img= img.view(1,3,32,32).to(Trainer.device)

results = [conv_layers[0](img)]
for i in range(1, len(conv_layers)):
    results.append(conv_layers[i](results[-1]))
outputs = results



for num_layer in range(len(outputs)):
    plt.figure(figsize=(50, 10))
    layer_viz = outputs[num_layer][0, :, :, :]
    layer_viz = layer_viz.data
#     print("Layer ",num_layer+1)
#     filters=[]
    for i, filter in enumerate(layer_viz):
#         filters.append(filter)
        if i == 16: 
            break
        plt.subplot(2, 8, i + 1)
        plt.imshow(filter.cpu(), cmap='gray')
        plt.axis("off")
# Out:
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/2113832423.py in <module>
#      45             break
#      46         plt.subplot(2, 8, i + 1)
# ---> 47         plt.imshow(filter, cmap='gray')
#      48         plt.axis("off")
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2907         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2908         url=url, **({"data": data} if data is not None else {}),
# -> 2909         **kwargs)
#    2910     sci(__ret)
#    2911     return __ret
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     694         if isinstance(A, PIL.Image.Image):
#     695             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 696         self._A = cbook.safe_masked_invalid(A, copy=True)
#     697
#     698         if (self._A.dtype != np.uint8 and
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     734
#     735 def safe_masked_invalid(x, copy=False):
# --> 736     x = np.array(x, subok=True, copy=copy)
#     737     if not x.dtype.isnative:
#     738         # If we have already made a copy, do the byteswap in place, else make a
#
# ~\anaconda3\envs\UoA-DL\lib\site-packages\torch\_tensor.py in __array__(self, dtype)
#     641             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     642         if dtype is None:
# --> 643             return self.numpy()
#     644         else:
#     645             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
Trainer.predict(img)

# %%
Trainer.get_feature_reduction()
